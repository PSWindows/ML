# %%
import pandas as pd
messages=pd.read_csv("spam.csv", encoding="latin1", sep=',', names=['label', 'message', "Test1", "Test2", "Test3"]).iloc[:, :2]

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asif\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
lem=WordNetLemmatizer()

# %%
corpus = []
for i in range(len(messages)):
    # Replace non-alphabet characters with space
    review = re.sub('[^a-zA-Z]', ' ', messages['message'][i])
    review = review.lower()  # Convert to lowercase
    review = review.split()  # Split into words
    review=[lem.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)
    corpus.append(review)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=100, binary=True)
X=cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'go': np.int64(23),
#  'great': np.int64(27),
#  'got': np.int64(26),
#  'wat': np.int64(90),
#  'ok': np.int64(59),
#  'free': np.int64(19),
#  'win': np.int64(94),
#  'text': np.int64(79),
#  'txt': np.int64(86),
#  'say': np.int64(70),
#  'already': np.int64(0),
#  'think': np.int64(82),
#  'life': np.int64(39),
#  'hey': np.int64(30),
#  'week': np.int64(92),
#  'back': np.int64(5),
#  'like': np.int64(40),
#  'still': np.int64(75),
#  'send': np.int64(72),
#  'friend': np.int64(20),
#  'prize': np.int64(65),
#  'claim': np.int64(9),
#  'call': np.int64(6),
#  'mobile': np.int64(50),
#  'co': np.int64(10),
#  'home': np.int64(32),
#  'want': np.int64(89),
#  'today': np.int64(84),
#  'cash': np.int64(8),
#  'day': np.int64(15),
#  'reply': np.int64(67),
#  'www': np.int64(96),
#  'right': np.int64(68),
#  'take': np.int64(77),
#  'time': np.int64(83),
#  'message': np.int64(47),
#  'com': np.int64(11),
#  'oh': np.int64(58),
#  'yes': np.int64(99),
#  'make': np.int64(45),
#  'way': np.int64(91),
#  'dont': np.int64(17),
#  'miss': np.int64(49),
#  'ur': np.int64(88),
#  'going': np.int64(24),
#  'da': np.int64(14),
#  'lor': np.int64(42),
#  'meet': np.int64(46),
#  'really': np.int64(66),
#  'know': np.int64(35),
#  'lol': np.int64(41),
#  'love': np.int64(43),
#  'let': np.int64(38),
#  'work': np.int64(95),
#  'yeah': np.int64(97),
#  'tell': np.int64(78),
#  'anything': np.int64(2),
#  'thanks': np.int64(80),
#  'uk': np.int64(87),
#  'please': np.int64(63),
#  'msg': np.int64(52),
#  'see': np.int64(71),
#  'pls': np.int64(64),
#  'need': np.int64(54),
#  'tomorrow': np.int64(85),
#  'hope': np.int64(33),
#  'well': np.int64(93),
#  'lt': np.int64(44),
#  'gt': np.int64(28),
#  'get': np.int64(21),
#  'ask': np.int64(3),
#  'morning': np.int64(51),
#  'happy': np.int64(29),
#  'sorry': np.int64(74),
#  'give': np.int64(22),
#  'new': np.int64(55),
#  'find': np.int64(18),
#  'year': np.int64(98),
#  'later': np.int64(37),
#  'pick': np.int64(62),
#  'good': np.int64(25),
#  'come': np.int64(12),
#  'said': np.int64(69),
#  'hi': np.int64(31),
#  'babe': np.int64(4),
#  'im': np.int64(34),
#  'much': np.int64(53),
#  'stop': np.int64(76),
#  'one': np.int64(60),
#  'night': np.int64(56),
#  'service': np.int64(73),
#  'dear': np.int64(16),
#  'thing': np.int64(81),
#  'contact': np.int64(13),
#  'last': np.int64(36),
#  'min': np.int64(48),
#  'number': np.int64(57),
#  'also': np.int64(1),
#  'care': np.int64(7),
#  'phone': np.int64(61)}

# %%
# Create the Bag if words model with ngram
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=500, binary=True, ngram_range=(2,2))
X=cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'free entry': np.int64(128),
#  'rate apply': np.int64(336),
#  'per request': np.int64(307),
#  'callertune caller': np.int64(43),
#  'caller press': np.int64(41),
#  'press copy': np.int64(329),
#  'friend callertune': np.int64(132),
#  'claim call': np.int64(57),
#  'call claim': np.int64(24),
#  'claim code': np.int64(58),
#  'entitled update': np.int64(115),
#  'update latest': np.int64(432),
#  'latest colour': np.int64(211),
#  'free call': np.int64(126),
#  'call mobile': np.int64(32),
#  'mobile update': np.int64(263),
#  'chance win': np.int64(56),
#  'win cash': np.int64(479),
#  'reply hl': np.int64(342),
#  'hl info': np.int64(185),
#  'txt word': np.int64(427),
#  'dont miss': np.int64(105),
#  'let know': np.int64(218),
#  'feel like': np.int64(120),
#  'yeah got': np.int64(495),
#  'mobile charged': np.int64(259),
#  'go home': np.int64(150),
#  'anything lor': np.int64(4),
#  'call reply': np.int64(36),
#  'nokia mobile': np.int64(288),
#  'mobile free': np.int64(260),
#  'free camcorder': np.int64(127),
#  'please call': np.int64(313),
#  'delivery tomorrow': np.int64(99),
#  'lt gt': np.int64(234),
#  'missed call': np.int64(257),
#  'want go': np.int64(466),
#  'first time': np.int64(125),
#  'like lt': np.int64(222),
#  'sm ac': np.int64(374),
#  'bx ip': np.int64(21),
#  'sorry call': np.int64(379),
#  'call later': np.int64(30),
#  'later meeting': np.int64(208),
#  'awarded bonus': np.int64(10),
#  'prize call': np.int64(332),
#  'ur awarded': np.int64(433),
#  'hi babe': np.int64(182),
#  'call free': np.int64(26),
#  'thats cool': np.int64(408),
#  'hi hi': np.int64(184),
#  'wen ur': np.int64(478),
#  'call customer': np.int64(25),
#  'customer service': np.int64(88),
#  'service representative': np.int64(366),
#  'pm guaranteed': np.int64(319),
#  'guaranteed cash': np.int64(169),
#  'cash prize': np.int64(53),
#  'need get': np.int64(274),
#  'get home': np.int64(140),
#  'trying contact': np.int64(422),
#  'contact last': np.int64(78),
#  'last weekend': np.int64(207),
#  'weekend draw': np.int64(474),
#  'draw show': np.int64(108),
#  'show prize': np.int64(368),
#  'prize guaranteed': np.int64(334),
#  'guaranteed call': np.int64(168),
#  'valid hr': np.int64(451),
#  'hr ppm': np.int64(192),
#  'said happy': np.int64(352),
#  'happy day': np.int64(177),
#  'day bos': np.int64(90),
#  'special askd': np.int64(384),
#  'specially selected': np.int64(386),
#  'selected receive': np.int64(361),
#  'speak live': np.int64(382),
#  'live operator': np.int64(225),
#  'operator claim': np.int64(302),
#  'private account': np.int64(331),
#  'account statement': np.int64(0),
#  'statement show': np.int64(388),
#  'call identifier': np.int64(27),
#  'identifier code': np.int64(194),
#  'code expires': np.int64(63),
#  'urgent mobile': np.int64(447),
#  'bonus caller': np.int64(17),
#  'caller prize': np.int64(42),
#  'contact call': np.int64(76),
#  'call landline': np.int64(29),
#  'voda number': np.int64(456),
#  'number ending': np.int64(293),
#  'ending selected': np.int64(114),
#  'receive award': np.int64(339),
#  'match please': np.int64(244),
#  'wat time': np.int64(469),
#  'time finish': np.int64(410),
#  'long time': np.int64(227),
#  'give call': np.int64(146),
#  'dear call': np.int64(95),
#  'sony dvd': np.int64(378),
#  'want get': np.int64(465),
#  'ur mob': np.int64(440),
#  'join uk': np.int64(197),
#  'go get': np.int64(149),
#  'sir waiting': np.int64(371),
#  'gud ni': np.int64(172),
#  'yes see': np.int64(499),
#  'per msg': np.int64(306),
#  'reply stop': np.int64(343),
#  'stop end': np.int64(390),
#  'new year': np.int64(283),
#  'miss already': np.int64(256),
#  'new job': np.int64(278),
#  'inviting friend': np.int64(196),
#  'friend reply': np.int64(133),
#  'reply yes': np.int64(344),
#  'see www': np.int64(360),
#  'www sm': np.int64(490),
#  'stop send': np.int64(392),
#  'send stop': np.int64(364),
#  'stop frnd': np.int64(391),
#  'ur mobile': np.int64(441),
#  'urgent trying': np.int64(449),
#  'co uk': np.int64(62),
#  'keep touch': np.int64(198),
#  'gr day': np.int64(161),
#  'gud mrng': np.int64(171),
#  'nice day': np.int64(285),
#  'person story': np.int64(309),
#  'see tomorrow': np.int64(359),
#  'lt decimal': np.int64(233),
#  'decimal gt': np.int64(97),
#  'like dat': np.int64(220),
#  'get ready': np.int64(141),
#  'hope great': np.int64(190),
#  'new mobile': np.int64(279),
#  'txt nokia': np.int64(425),
#  'good morning': np.int64(158),
#  'ur friend': np.int64(435),
#  'secret admirer': np.int64(357),
#  'admirer looking': np.int64(2),
#  'looking make': np.int64(229),
#  'make contact': np.int64(238),
#  'contact find': np.int64(77),
#  'find reveal': np.int64(124),
#  'reveal think': np.int64(345),
#  'think ur': np.int64(409),
#  'ur special': np.int64(444),
#  'special call': np.int64(385),
#  'oh ok': np.int64(296),
#  'good night': np.int64(159),
#  'congratulation ur': np.int64(75),
#  'gift guaranteed': np.int64(144),
#  'draw txt': np.int64(109),
#  'txt music': np.int64(424),
#  'music tncs': np.int64(270),
#  'www ldew': np.int64(489),
#  'ldew com': np.int64(215),
#  'com win': np.int64(68),
#  'win ppmx': np.int64(481),
#  'ppmx age': np.int64(328),
#  'day da': np.int64(91),
#  'lemme know': np.int64(216),
#  'get back': np.int64(138),
#  'tried contact': np.int64(421),
#  'anytime network': np.int64(5),
#  'network min': np.int64(276),
#  'unlimited text': np.int64(431),
#  'camcorder reply': np.int64(44),
#  'reply call': np.int64(341),
#  'text stop': np.int64(405),
#  'po box': np.int64(321),
#  'another day': np.int64(3),
#  'last night': np.int64(204),
#  'camera phone': np.int64(47),
#  'cant pick': np.int64(48),
#  'pick phone': np.int64(312),
#  'phone right': np.int64(311),
#  'right pls': np.int64(346),
#  'pls send': np.int64(317),
#  'send message': np.int64(363),
#  'great day': np.int64(162),
#  'mobile mths': np.int64(261),
#  'colour camera': np.int64(66),
#  'camera mobile': np.int64(46),
#  'babe love': np.int64(14),
#  'love ya': np.int64(232),
#  'cool text': np.int64(81),
#  'per minute': np.int64(305),
#  'valentine day': np.int64(450),
#  'send go': np.int64(362),
#  'msg rcvd': np.int64(267),
#  'ur cash': np.int64(434),
#  'cash balance': np.int64(51),
#  'balance currently': np.int64(15),
#  'currently pound': np.int64(87),
#  'pound maximize': np.int64(327),
#  'maximize ur': np.int64(248),
#  'cash send': np.int64(54),
#  'hg suite': np.int64(181),
#  'suite land': np.int64(394),
#  'land row': np.int64(201),
#  'row hl': np.int64(348),
#  'good afternoon': np.int64(155),
#  'take care': np.int64(396),
#  'latest motorola': np.int64(212),
#  'double min': np.int64(107),
#  'call mobileupd': np.int64(33),
#  'mobileupd call': np.int64(264),
#  'call optout': np.int64(34),
#  'gt min': np.int64(165),
#  'thanks ringtone': np.int64(407),
#  'ringtone order': np.int64(347),
#  'per week': np.int64(308),
#  'min txts': np.int64(255),
#  'half price': np.int64(175),
#  'line rental': np.int64(224),
#  'latest camera': np.int64(210),
#  'phone free': np.int64(310),
#  'call back': np.int64(22),
#  'good evening': np.int64(157),
#  'txt stop': np.int64(426),
#  'fullonsms com': np.int64(135),
#  'yan jiu': np.int64(493),
#  'dating service': np.int64(89),
#  'box sk': np.int64(19),
#  'dont want': np.int64(106),
#  'entry weekly': np.int64(116),
#  'pobox wq': np.int64(324),
#  'last week': np.int64(206),
#  'find call': np.int64(122),
#  'mobile number': np.int64(262),
#  'number awarded': np.int64(292),
#  'awarded prize': np.int64(12),
#  'call land': np.int64(28),
#  'land line': np.int64(200),
#  'line claim': np.int64(223),
#  'claim valid': np.int64(61),
#  'ok ok': np.int64(298),
#  'watching tv': np.int64(470),
#  'call call': np.int64(23),
#  'cost ppm': np.int64(83),
#  'call min': np.int64(31),
#  'wc xx': np.int64(471),
#  'gt th': np.int64(167),
#  'gt dollar': np.int64(163),
#  'gt lt': np.int64(164),
#  'well done': np.int64(477),
#  'hope good': np.int64(189),
#  'good day': np.int64(156),
#  'help call': np.int64(179),
#  'free text': np.int64(131),
#  'text back': np.int64(402),
#  'tenerife holiday': np.int64(401),
#  'holiday cash': np.int64(188),
#  'award call': np.int64(9),
#  'sae box': np.int64(349),
#  'cant wait': np.int64(49),
#  'visit www': np.int64(455),
#  'meeting call': np.int64(249),
#  'prize claim': np.int64(333),
#  'latest nokia': np.int64(213),
#  'gb ipod': np.int64(137),
#  'mp player': np.int64(266),
#  'tone reply': np.int64(418),
#  'tone txt': np.int64(419),
#  'http www': np.int64(193),
#  'prize nd': np.int64(335),
#  'nd attempt': np.int64(272),
#  'attempt contact': np.int64(7),
#  'claim ur': np.int64(60),
#  'ur worth': np.int64(445),
#  'worth discount': np.int64(485),
#  'discount voucher': np.int64(103),
#  'text yes': np.int64(406),
#  'savamob member': np.int64(353),
#  'member offer': np.int64(250),
#  'offer mobile': np.int64(294),
#  'show un': np.int64(369),
#  'un redeemed': np.int64(430),
#  'redeemed point': np.int64(340),
#  'point call': np.int64(325),
#  'love go': np.int64(231),
#  'go day': np.int64(148),
#  'kiss across': np.int64(199),
#  'across sea': np.int64(1),
#  'later tonight': np.int64(209),
#  'many many': np.int64(242),
#  'many happy': np.int64(241),
#  'happy birthday': np.int64(176),
#  'yar lor': np.int64(494),
#  'waiting call': np.int64(459),
#  'new video': np.int64(282),
#  'video phone': np.int64(452),
#  'one day': np.int64(300),
#  'shopping spree': np.int64(367),
#  'service announcement': np.int64(365),
#  'sleep well': np.int64(373),
#  'ok lor': np.int64(297),
#  'want come': np.int64(464),
#  'many time': np.int64(243),
#  'make sure': np.int64(239),
#  'dear voucher': np.int64(96),
#  'voucher holder': np.int64(457),
#  'stop text': np.int64(393),
#  'gud evng': np.int64(170),
#  'going home': np.int64(153),
#  'every week': np.int64(117),
#  'say hi': np.int64(356),
#  'come home': np.int64(70),
#  'year old': np.int64(497),
#  'pls call': np.int64(314),
#  'message waiting': np.int64(251),
#  'look like': np.int64(228),
#  'offer new': np.int64(295),
#  'new nokia': np.int64(280),
#  'good time': np.int64(160),
#  'day send': np.int64(93),
#  'next week': np.int64(284),
#  'happy new': np.int64(178),
#  'every wk': np.int64(118),
#  'wk txt': np.int64(484),
#  'gt minute': np.int64(166),
#  'national rate': np.int64(271),
#  'savamob pobox': np.int64(354),
#  'pobox uz': np.int64(323),
#  'lt time': np.int64(235),
#  'time gt': np.int64(411),
#  'free st': np.int64(130),
#  'st week': np.int64(387),
#  'week nokia': np.int64(472),
#  'nokia tone': np.int64(289),
#  'tone ur': np.int64(420),
#  'week txt': np.int64(473),
#  'nokia get': np.int64(287),
#  'get txting': np.int64(142),
#  'txting tell': np.int64(428),
#  'tell ur': np.int64(400),
#  'ur mate': np.int64(439),
#  'mate www': np.int64(246),
#  'www getzed': np.int64(488),
#  'getzed co': np.int64(143),
#  'uk pobox': np.int64(429),
#  'wq norm': np.int64(487),
#  'norm tone': np.int64(290),
#  'awarded either': np.int64(11),
#  'cd gift': np.int64(55),
#  'gift voucher': np.int64(145),
#  'weekly draw': np.int64(476),
#  'ok take': np.int64(299),
#  'teasing kiss': np.int64(399),
#  'comuk net': np.int64(73),
#  'net login': np.int64(275),
#  'say hello': np.int64(355),
#  'didnt get': np.int64(101),
#  'morning dear': np.int64(265),
#  'min text': np.int64(254),
#  'landline complimentary': np.int64(202),
#  'cash await': np.int64(50),
#  'await collection': np.int64(8),
#  'collection sae': np.int64(65),
#  'sae po': np.int64(350),
#  'wan go': np.int64(461),
#  'price line': np.int64(330),
#  'dont know': np.int64(104),
#  'text call': np.int64(403),
#  'sk xh': np.int64(372),
#  'light someone': np.int64(219),
#  'contact today': np.int64(79),
#  'today draw': np.int64(415),
#  'come back': np.int64(69),
#  'wait till': np.int64(458),
#  'congrats mobile': np.int64(74),
#  'videophones call': np.int64(454),
#  'call videochat': np.int64(40),
#  'videochat wid': np.int64(453),
#  'mate play': np.int64(245),
#  'game dload': np.int64(136),
#  'music noline': np.int64(269),
#  'call tomorrow': np.int64(39),
#  'wan come': np.int64(460),
#  'mob every': np.int64(258),
#  'gud nyt': np.int64(173),
#  'someone know': np.int64(376),
#  'call sir': np.int64(37),
#  'final attempt': np.int64(121),
#  'txt chat': np.int64(423),
#  'would like': np.int64(486),
#  'awarded sipix': np.int64(13),
#  'sipix digital': np.int64(370),
#  'digital camera': np.int64(102),
#  'camera call': np.int64(45),
#  'landline delivery': np.int64(203),
#  'delivery within': np.int64(100),
#  'within day': np.int64(483),
#  'sorry da': np.int64(380),
#  'important information': np.int64(195),
#  'lucky day': np.int64(237),
#  'day find': np.int64(92),
#  'find log': np.int64(123),
#  'log onto': np.int64(226),
#  'onto http': np.int64(301),
#  'www urawinner': np.int64(491),
#  'urawinner com': np.int64(446),
#  'com fantastic': np.int64(67),
#  'hl ldn': np.int64(186),
#  'yeah probably': np.int64(496),
#  'take part': np.int64(397),
#  'ur home': np.int64(437),
#  'half hour': np.int64(174),
#  'tone free': np.int64(417),
#  'weekly comp': np.int64(475),
#  'min stop': np.int64(253),
#  'sound like': np.int64(381),
#  'network operator': np.int64(277),
#  'hey babe': np.int64(180),
#  'ur smile': np.int64(443),
#  'something like': np.int64(377),
#  'ur heart': np.int64(436),
#  'fantasy call': np.int64(119),
#  'call per': np.int64(35),
#  'per min': np.int64(304),
#  'min ntt': np.int64(252),
#  'ntt ltd': np.int64(291),
#  'ltd po': np.int64(236),
#  'box croydon': np.int64(18),
#  'croydon cr': np.int64(86),
#  'cr wb': np.int64(85),
#  'sweet dream': np.int64(395),
#  'go back': np.int64(147),
#  'cash every': np.int64(52),
#  'ur sm': np.int64(442),
#  'friendship good': np.int64(134),
#  'wan meet': np.int64(462),
#  'rate call': np.int64(337),
#  'bt national': np.int64(20),
#  'dun haf': np.int64(110),
#  'pls pls': np.int64(316),
#  'go well': np.int64(151),
#  'win free': np.int64(480),
#  'plus free': np.int64(318),
#  'want know': np.int64(467),
#  'wan watch': np.int64(463),
#  'around lt': np.int64(6),
#  'let go': np.int64(217),
#  'ur life': np.int64(438),
#  'yes princess': np.int64(498),
#  'coming home': np.int64(72),
#  'free msg': np.int64(129),
#  'dun wan': np.int64(111),
#  'come tomorrow': np.int64(71),
#  'nd time': np.int64(273),
#  'time tried': np.int64(412),
#  'claim easy': np.int64(59),
#  'easy call': np.int64(113),
#  'god love': np.int64(152),
#  'love amp': np.int64(230),
#  'urgent please': np.int64(448),
#  'costa del': np.int64(84),
#  'del sol': np.int64(98),
#  'sol holiday': np.int64(375),
#  'holiday await': np.int64(187),
#  'collection call': np.int64(64),
#  'call toclaim': np.int64(38),
#  'toclaim sae': np.int64(413),
#  'sae tc': np.int64(351),
#  'tc pobox': np.int64(398),
#  'pobox stockport': np.int64(322),
#  'stockport sk': np.int64(389),
#  'xh cost': np.int64(492),
#  'cost pm': np.int64(82),
#  'pm max': np.int64(320),
#  'max min': np.int64(247),
#  'going sleep': np.int64(154),
#  'speak soon': np.int64(383),
#  'hi darlin': np.int64(183),
#  'get free': np.int64(139),
#  'dunno lei': np.int64(112),
#  'pls convey': np.int64(315),
#  'convey birthday': np.int64(80),
#  'birthday wish': np.int64(16),
#  'wish nimya': np.int64(482),
#  'nimya pls': np.int64(286),
#  'today birthday': np.int64(414),
#  'man last': np.int64(240),
#  'day wife': np.int64(94),
#  'sed sexy': np.int64(358),
#  'latr wid': np.int64(214),
#  'like hour': np.int64(221),
#  'tone arrive': np.int64(416),
#  'murdered lt': np.int64(268),
#  'house maid': np.int64(191),
#  'post office': np.int64(326),
#  'last nite': np.int64(205),
#  'new tone': np.int64(281),
#  'orange tariff': np.int64(303),
#  'want new': np.int64(468),
#  'text free': np.int64(404),
#  'really need': np.int64(338)}
